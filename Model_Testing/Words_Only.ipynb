# %% [markdown]
# # Natural Language Processing - Bill Text Exploration

# %% [markdown]
# **This analysis includes combined text of bill titles and summaries**
#
# Transform the raw data into feature vectors and these new features will be created using the existing dataset. Structure as follows:
#
# Data Exploration
# - Word Cloud
#
# Vectorizers
# - Custom and Spacy Tokenizer
# - Count Vectors as features
# - TF-IDF Vectors as features
#
# - Word level
# - N-Gram level
#
# Character level
# - Word Embeddings as features
# - Text / NLP based features
# - Topic Models as features
#
# https://www.analyticsvidhya.com/blog/2018/04/a-comprehensive-guide-to-understand-and-implement-text-classification-in-python/

# %%
import mysql.connector 
import numpy as np
import pandas as pd
import config_final
import requests

from sodapy import Socrata
import sqlalchemy as db

import config_final as config
from schema import DbSchema


bills_db = DbSchema(config)

# topics_db = bills_db.query('SELECT * from topics')

# %%
passed_bills = bills_db.query("""
    SELECT
        cb.BillID,
        cb.Cong,
        cb.NameFull,
        cb.Party,
        cb.Summary,
        cb.Title,
        tp.dominant_topic
    FROM con_bills.current_bills as cb
    JOIN con_bills.topics as tp
    ON cb.BillID = tp.BillID
    WHERE cb.PassH = 1
    AND cb.Cong >=110
    """)
passed_bills.head(20)
# Out:
#          BillID  Cong           NameFull  Party  \
# 0      110-HR-1   110    Bennie Thompson  100.0
# 1   110-HR-1003   110       Diane Watson  100.0
# 2   110-HR-1006   110          Don Young  200.0
# 3   110-HR-1011   110  Frederick Boucher  100.0
# 4   110-HR-1014   110         Lois Capps  100.0
# 5   110-HR-1019   110       Luis Fortuno  200.0
# 6   110-HR-1021   110       Barney Frank  100.0
# 7   110-HR-1025   110        Jerry Moran  200.0
# 8   110-HR-1036   110          Don Young  200.0
# 9   110-HR-1045   110    Leonard Boswell  100.0
# 10  110-HR-1047   110           Wm. Clay  100.0
# 11  110-HR-1051   110          Rush Holt  100.0
# 12  110-HR-1065   110       Dennis Moore  100.0
# 13  110-HR-1066   110       Barney Frank  100.0
# 14  110-HR-1068   110        Brian Baird  100.0
# 15  110-HR-1080   110      Barbara Cubin  200.0
# 16  110-HR-1084   110           Sam Farr  100.0
# 17  110-HR-1100   110       Heath Shuler  100.0
# 18  110-HR-1108   110       Henry Waxman  100.0
# 19  110-HR-1114   110          Don Young  200.0
#
#                                               Summary  \
# 0   Implementing Recommendations of the 9/11 Commi...
# 1   This measure has not been amended since it was...
# 2   Marine Mammal Rescue Assistance Amendments of ...
# 3   Virginia Ridge and Valley Act of 2007 - Design...
# 4   Heart Disease Education, Analysis Research, an...
# 5   (This measure has not been amended since it wa...
# 6   (This measure has not been amended since it wa...
# 7   (This measure has not been amended since it wa...
# 8   Requires the Administrator of the General Serv...
# 9   (This measure has not been amended since it wa...
# 10  (This measure has not been amended since it wa...
# 11  National STEM Scholarship Database Act - Direc...
# 12  (This measure has not been amended since it wa...
# 13  (This measure has not been amended since it wa...
# 14  Amends the High-Performance Computing Act of 1...
# 15  (This measure has not been amended since it wa...
# 16  (This measure has not been amended since it wa...
# 17  (This measure has not been amended since it wa...
# 18  Family Smoking Prevention and Tobacco Control ...
# 19  (This measure has not been amended since it wa...
#
#                                                 Title  dominant_topic
# 0   To provide for the implementation of the recom...               5
# 1   To amend the Foreign Affairs Reform and Restru...               7
# 2   To amend the provisions of law relating to the...               0
# 3   To designate additional National Forest System...              11
# 4   To amend the Federal Food, Drug, and Cosmetic ...              12
# 5   To designate the United States customhouse bui...               7
# 6   To direct the Secretary of the Interior to con...              11
# 7   To authorize the Secretary of the Interior to ...              11
# 8   To authorize the Administrator of General Serv...               9
# 9   To designate the Federal building located at 2...               7
# 10  To authorize the Secretary of the Interior to ...              11
# 11  To direct the Secretary of Education to establ...               8
# 12  To streamline the regulation of nonadmitted in...               7
# 13  To increase community development investments ...               7
# 14  To amend the High-Performance Computing Act of...               1
# 15  To modify the boundaries of Grand Teton Nation...               7
# 16  To amend the Foreign Assistance Act of 1961, t...               7
# 17  To revise the boundary of the Carl Sandburg Ho...               7
# 18  To protect the public health by providing the ...              10
# 19  To require the Secretary of the Interior, acti...              11

# %%
not_passed_bills = bills_db.query("""
    SELECT
        cb.BillID,
        cb.Cong,
        cb.NameFull,
        cb.Party,
        cb.Summary,
        cb.Title,
        tp.dominant_topic
    FROM con_bills.current_bills as cb
    JOIN con_bills.topics as tp
    ON cb.BillID = tp.BillID
    WHERE cb.PassH = 0
    AND cb.Cong >=110
    """)
not_passed_bills.head()
# Out:
#         BillID  Cong        NameFull  Party  \
# 0    110-HR-10   110    Nancy Pelosi  100.0
# 1   110-HR-100   110     Susan Davis  100.0
# 2  110-HR-1000   110  Eleanor Norton  100.0
# 3  110-HR-1001   110     John Spratt  100.0
# 4  110-HR-1002   110     John Spratt  100.0
#
#                                              Summary  \
# 0
# 1  Veterans' Equity in Education Act of 2007 - Am...
# 2  Edward William Brooke III Congressional Gold M...
# 3  Amends the Caribbean Basin Economic Recovery A...
# 4  Imposes an additional duty rate of 27.5 % ad v...
#
#                                                Title  dominant_topic
# 0                              Reserved for Speaker.              10
# 1  To amend the Higher Education Act of 1965 to p...               4
# 2  To award a congressional gold medal to Edward ...              10
# 3  To amend the Haitian Hemispheric Opportunity t...               5
# 4  To authorize appropriate action if the negotia...               1

# %%
passed_bills.shape
# Out:
# (4025, 6)

# %%
not_passed_bills.shape
# Out:
# (47042, 7)

# %% [markdown]
# **Final Cleaning:**

# %%
def final_clean(df):
    
    df['Summary'].fillna('None', inplace = True)
    
    df['combined_text'] = df[['Title', 'Summary']].astype(str).apply(' '.join, axis=1)
    
    return df

# %%
passed_df = final_clean(passed_bills)

# %%
passed_df = final_clean(not_passed_bills)

# %%
passed_df.shape
# Out:
# (4025, 7)

# %%
not_passed_df.shape
# Out:
# (47042, 7)

# %% [markdown]
# **Combine Title and Summary columns:**

# %% [markdown]
# # Review of Text

# %% [markdown]
# **Split Training and Testing Data**

# %%
from sklearn import preprocessing

# %%
# from sklearn.model_selection import train_test_split

X = passed_df['Title']


X1 = not_passed_df['Title']

# %%
# X_train, X_test, y_train1, y_test1 = train_test_split(X, y, random_state=2)

# %%
# passed_df['combined_text']

# %%
passed_df.loc[10][6]
# Out:
# "To authorize the Secretary of the Interior to conduct a study to determine the suitability and feasibility of designating the Soldiers' Memorial Military Museum located in St. Louis, Missouri, as a unit of the National Park System. (This measure has not been amended since it was introduced. The expanded summary of the House passed version is repeated here.)"

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# **Cleaning Text**
#
# Test both the spacy tokenizer and personalized tokenizer against the data.

# %%
import spacy
from spacy.lang.en import English
import en_core_web_sm
import string
import re

nlp = English()
stop_words = spacy.lang.en.stop_words.STOP_WORDS

nlp.Defaults.stop_words |= {"bill","amend", "purpose", "united", "state", "states", "secretary", "act", "federal", "provide"}

replace_with_space = re.compile('[/(){}\[\]\|@,;]')

just_words = re.compile('[^a-zA-Z\s]')

# %%
# Create our list of punctuation marks
punctuations = string.punctuation

# Create our list of stopwords
nlp = spacy.load('en_core_web_sm')
stop_words = spacy.lang.en.stop_words.STOP_WORDS

def tokenizer(text):
    
    #lowercase everything
    lower_text = text.lower()
    
    #remove punctuation
#     no_pun_text = lower_text.translate(str.maketrans('', '', string.punctuation))
    
    #get rid of weird characters
    text = replace_with_space.sub('',lower_text)
    
    #remove numbers
    just_words_text = just_words.sub('', text)
    
    #add spacy tokenizer
    mytokens = nlp(just_words_text, disable=['parser', 'ner'])
#     print(mytokens)
    
    #for POS tagging
#     mytokens = [word for word in mytokens if (word.pos_ == 'NOUN') or (word.pos_ == 'VERB') or (word.pos_ == 'ADJ') or (word.pos_ == 'ADV')]
    
    #lemmatize
    mytokens = [word.lemma_.strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    
    #MAP SPECIFIC WORDS to others (veteran from veterans)

    #add stopwords
    mytokens = [word for word in mytokens if word not in stop_words and word not in punctuations]
    
    return mytokens

# %%
test_fun = passed_df.iloc[2233][2:6]
test_fun
# Out:
# Party                                                           200
# Summary           FHA Emergency Fiscal Solvency Act of 2012 - (S...
# Title             To help ensure the fiscal solvency of the FHA ...
# dominant_topic                                                    8
# Name: 2233, dtype: object

# %%
tokenizer(test_fun)
# Out:
# ['help',
#  'ensure',
#  'fiscal',
#  'solvency',
#  'fha',
#  'mortgage',
#  'insurance',
#  'program',
#  'housing',
#  'urban',
#  'development',
#  'fha',
#  'emergency',
#  'fiscal',
#  'solvency',
#  'sec',
#  'national',
#  'housing',
#  'nha',
#  'direct',
#  'housing',
#  'urban',
#  'development',
#  'hud',
#  'currently',
#  'authorize',
#  'establish',
#  'collect',
#  'additional',
#  'annual',
#  'premium',
#  'payment',
#  'year',
#  'term',
#  'insured',
#  'mortgage',
#  'remain',
#  'insured',
#  'principal',
#  'balance',
#  'certain',
#  'adjustment',
#  'certain',
#  'period',
#  'increase',
#  'year',
#  'annual',
#  'premium',
#  'insured',
#  'mortgage',
#  'original',
#  'principal',
#  'obligation',
#  'exceed',
#  'remain',
#  'principal',
#  'balance']

# %% [markdown]
# **CountVectorizer**
#
# Every row represents a document in the corpus, every column represents a term in the document, every cell represents the frequency count of a particular term in a particular document.
#
# Tuning: analyzer, vectorizer, max_features, max_df, min_df, n_grams

# %% [markdown]
# Explore:
#
# min_df:
#
# - min_df = 0.01 means "ignore terms that appear in less than 1% of the documents".
# - min_df = 5 means "ignore terms that appear in less than 5 documents".
#
# max_df: Attempt to remove heavily used words.
#
# - max_df = 0.50 means "ignore terms that appear in more than 50% of the documents".
# - max_df = 25 means "ignore terms that appear in more than 25 documents".

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(tokenizer = tokenizer, max_df = 0.90, max_features = 10000) # max_df=0.90, min_df=10
transformed = vectorizer.fit_transform(X)
print(len(vectorizer.get_feature_names()))
# Out:
# 5903

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer1 = CountVectorizer(tokenizer = tokenizer, max_df = 0.90, max_features = 10000) # max_df=0.90, min_df=10
transformed1 = vectorizer1.fit_transform(X1)
print(len(vectorizer1.get_feature_names()))
# Out:
# 10000

# %% [markdown]
# **Exploring Stored Words**

# %% [markdown]
# Think about the number of words and how to decrease that list!
#
# Lemmatization should be something to further consider, also limiting specific words (pronouns?) used often

# %%
len(vectorizer.get_feature_names())
# Out:
# 10000

# %%
vectorizer.get_feature_names
# Out:
# <bound method CountVectorizer.get_feature_names of CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.9, max_features=10000, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=<function tokenizer at 0x1a42c001e0>,
#                 vocabulary=None)>

# %%
# vec = CountVectorizer().fit(corpus)
# bag_of_words = vec.transform(corpus)
def get_top_words(transformed_corpus, n=None):
    sum_words = transformed_corpus.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
#Top words in PASS
get_top_words(transformed)[:50]
# Out:
# [('service', 761),
#  ('certain', 631),
#  ('program', 601),
#  ('national', 556),
#  ('designate', 549),
#  ('code', 536),
#  ('title', 515),
#  ('locate', 495),
#  ('facility', 458),
#  ('office', 444),
#  ('authorize', 427),
#  ('security', 421),
#  ('postal', 383),
#  ('post', 367),
#  ('department', 354),
#  ('building', 331),
#  ('require', 323),
#  ('establish', 276),
#  ('land', 257),
#  ('extend', 253),
#  ('health', 247),
#  ('improve', 245),
#  ('veterans', 244),
#  ('year', 243),
#  ('public', 236),
#  ('fiscal', 209),
#  ('street', 208),
#  ('relate', 204),
#  ('system', 203),
#  ('direct', 201),
#  ('homeland', 197),
#  ('veteran', 191),
#  ('development', 188),
#  ('appropriation', 172),
#  ('water', 170),
#  ('law', 168),
#  ('agency', 168),
#  ('authority', 165),
#  ('interior', 164),
#  ('reauthorize', 159),
#  ('grant', 156),
#  ('protection', 150),
#  ('assistance', 149),
#  ('small', 149),
#  ('use', 149),
#  ('energy', 146),
#  ('new', 146),
#  ('fund', 145),
#  ('business', 142),
#  ('information', 141)]

# %%
#Top words in NOT PASS
get_top_words(transformed1)[:50]
# Out:
# [('eatonville', 8891),
#  ('definition', 7444),
#  ('prohibit', 4993),
#  ('santiago', 4881),
#  ('matching', 4551),
#  ('work', 4439),
#  ('lake', 4267),
#  ('mobilization', 3302),
#  ('reorganization', 2911),
#  ('carryover', 2879),
#  ('leahysmith', 2714),
#  ('currently', 2654),
#  ('restructure', 2199),
#  ('bush', 2170),
#  ('holloway', 2167),
#  ('fulbright', 2154),
#  ('positive', 2128),
#  ('m', 2050),
#  ('residual', 2050),
#  ('instance', 1978),
#  ('turnaround', 1858),
#  ('payable', 1766),
#  ('andean', 1705),
#  ('sovereign', 1702),
#  ('troy', 1628),
#  ('determine', 1590),
#  ('managerial', 1551),
#  ('polygraph', 1542),
#  ('cosigner', 1534),
#  ('clearance', 1533),
#  ('ildefonso', 1530),
#  ('spoil', 1514),
#  ('asbury', 1506),
#  ('longitudinal', 1417),
#  ('researcher', 1368),
#  ('organic', 1318),
#  ('royal', 1312),
#  ('knowledge', 1303),
#  ('revolve', 1286),
#  ('bountiful', 1214),
#  ('acre', 1202),
#  ('fashion', 1171),
#  ('en', 1155),
#  ('morning', 1136),
#  ('tropical', 1122),
#  ('millendermcdonald', 1106),
#  ('purchase', 1072),
#  ('successful', 1059),
#  ('rescission', 1051),
#  ('optimize', 1047)]

# %%
# import random

# #get ten random words from each

# for i in range(10):
#     word_id = random.randint(0, 2454) #second should be len of cv
#     print(vectorizer.get_feature_names()[word_id])

# %% [markdown]
# **Lemmas for Both Passed and Not Passed**

# %%
! pip install counter
# Out:
# Requirement already satisfied: counter in /Users/melissamunz/anaconda3/lib/python3.7/site-packages (1.0.0)

# %%
all_lemmas = df.combined_text.apply(tokenizer)
# Out:
# 0    [implementation, recommendation, national, com...
# 1                                   [reserve, speaker]
# 2    [high, education, prevent, veteran, contributi...
# 3    [award, congressional, gold, medal, edward, wi...
# 4    [haitian, hemispheric, opportunity, partnershi...
# Name: combined_text, dtype: object

# %%
all_lemmas.head()
# Out:
# 0    [implementation, recommendation, national, com...
# 1                                   [reserve, speaker]
# 2    [high, education, prevent, veteran, contributi...
# 3    [award, congressional, gold, medal, edward, wi...
# 4    [haitian, hemispheric, opportunity, partnershi...
# Name: combined_text, dtype: object

# %%
total_lemmas = []
for doc in all_lemmas:
    total_lemmas.extend(doc)

# %%
len(total_lemmas)
# Out:
# 1905442

# %%
from collections import Counter

all_words = dict(Counter(total_lemmas))

# %%
more_words = {key: value for key, value in all_words.items() if value >= 50}

# %%
more_words
# Out:
# {'implementation': 913,
#  'recommendation': 671,
#  'national': 13463,
#  'commission': 3347,
#  'terrorist': 579,
#  'attack': 306,
#  'implement': 1814,
#  'reserve': 1431,
#  'speaker': 175,
#  'high': 3022,
#  'education': 8243,
#  'prevent': 1786,
#  'veteran': 5667,
#  'contribution': 1493,
#  'benefit': 4577,
#  'reduce': 3077,
#  'student': 2992,
#  'financial': 2753,
#  'assistance': 6533,
#  'equity': 709,
#  'respect': 4020,
#  'calculation': 140,
#  'receive': 2941,
#  'eligible': 2793,
#  'year': 6629,
#  'factor': 318,
#  'eligibility': 1232,
#  'formula': 328,
#  'represent': 160,
#  'estimate': 337,
#  'educational': 2317,
#  'military': 2821,
#  'pay': 3476,
#  'deduction': 1805,
#  'behalf': 412,
#  'active': 945,
#  'duty': 9307,
#  'armed': 2266,
#  'force': 3307,
#  'award': 2728,
#  'congressional': 1657,
#  'gold': 626,
#  'medal': 797,
#  'edward': 92,
#  'william': 136,
#  'iii': 220,
#  'recognition': 675,
#  'service': 17856,
#  'nation': 639,
#  'african': 156,
#  'american': 2327,
#  'elect': 393,
#  'vote': 579,
#  'senate': 1104,
#  'haitian': 56,
#  'opportunity': 1622,
#  'partnership': 1082,
#  'extend': 7263,
#  'date': 1634,
#  'president': 2327,
#  'determine': 2176,
#  'haiti': 131,
#  'meet': 1188,
#  'certain': 12512,
#  'requirement': 5007,
#  'caribbean': 58,
#  'basin': 361,
#  'economic': 2059,
#  'recovery': 1041,
#  'meeting': 164,
#  'specify': 2460,
#  'political': 722,
#  'social': 6148,
#  'security': 12150,
#  'order': 1961,
#  'qualify': 664,
#  'preferential': 74,
#  'trade': 2039,
#  'provision': 3782,
#  'authorize': 7849,
#  'appropriate': 1609,
#  'action': 2852,
#  'negotiation': 155,
#  'people': 407,
#  'republic': 283,
#  'china': 177,
#  'regard': 2105,
#  'currency': 162,
#  'manipulation': 58,
#  'successful': 124,
#  'impose': 1470,
#  'additional': 1740,
#  'rate': 2722,
#  'article': 485,
#  'import': 532,
#  'growth': 652,
#  'product': 2591,
#  'manufacture': 883,
#  'peoples': 67,
#  'prc': 50,
#  'certify': 763,
#  'congress': 3204,
#  'longer': 111,
#  'exchange': 1791,
#  'dollar': 331,
#  'effective': 847,
#  'balance': 231,
#  'payment': 3917,
#  'gain': 589,
#  'unfair': 193,
#  'international': 1380,
#  'advantage': 177,
#  'value': 861,
#  'accordance': 462,
#  'accept': 404,
#  'trading': 287,
#  'policy': 2531,
#  'foreign': 2741,
#  'affair': 1588,
#  'reform': 2072,
#  'reauthorize': 1134,
#  'advisory': 596,
#  'public': 8286,
#  'diplomacy': 59,
#  'measure': 5194,
#  'introduce': 2590,
#  'summary': 3594,
#  'version': 2696,
#  'repeat': 2706,
#  'attorney': 1066,
#  'general': 2628,
#  'grant': 6978,
#  'improve': 4448,
#  'ability': 363,
#  'local': 3711,
#  'government': 4412,
#  'abduction': 58,
#  'child': 4903,
#  'family': 2832,
#  'member': 5037,
#  'prevention': 2255,
#  'direct': 9260,
#  'project': 3548,
#  'involve': 939,
#  'individual': 7222,
#  'suspect': 125,
#  'commit': 438,
#  'investigation': 700,
#  'law': 5215,
#  'enforcement': 2238,
#  'agency': 6731,
#  'case': 1178,
#  'training': 2283,
#  'respond': 307,
#  'recover': 160,
#  'outreach': 361,
#  'medium': 227,
#  'campaign': 634,
#  'educate': 140,
#  'parent': 707,
#  'danger': 141,
#  'authority': 2728,
#  'address': 1083,
#  'request': 1013,
#  'school': 4235,
#  'record': 953,
#  'require': 15317,
#  'percent': 640,
#  'cost': 3040,
#  'nonfederal': 364,
#  'source': 659,
#  'relief': 2946,
#  'relate': 4304,
#  'john': 245,
#  'h': 187,
#  'marine': 684,
#  'mammal': 113,
#  'rescue': 165,
#  'program': 18729,
#  'amendment': 971,
#  'protection': 6243,
#  'collection': 606,
#  'update': 406,
#  'practice': 1291,
#  'procedure': 1151,
#  'currently': 769,
#  'response': 829,
#  'agreement': 1949,
#  'deem': 373,
#  'responder': 210,
#  'employee': 5258,
#  'claim': 1685,
#  'repeal': 2554,
#  'longterm': 750,
#  'goal': 448,
#  'zero': 75,
#  'incidental': 65,
#  'mortality': 83,
#  'injury': 808,
#  'commercial': 1236,
#  'fishing': 255,
#  'operation': 1899,
#  'modify': 1666,
#  'reduction': 2012,
#  'plan': 4607,
#  'taking': 63,
#  'specified': 522,
#  'percentage': 583,
#  'awareness': 421,
#  'safe': 1483,
#  'use': 9048,
#  'internet': 775,
#  'establishment': 1295,
#  'office': 3760,
#  'safety': 3496,
#  'safeguard': 169,
#  'americas': 400,
#  'enhance': 1603,
#  'new': 3214,
#  'efficient': 564,
#  'technology': 2491,
#  'net': 353,
#  'ftc': 127,
#  'establish': 10223,
#  'head': 654,
#  'director': 1646,
#  'control': 3610,
#  'substance': 1208,
#  'exclude': 1209,
#  'industrial': 279,
#  'definition': 965,
#  'farming': 80,
#  'mean': 450,
#  'plant': 366,
#  'l': 130,
#  'concentration': 97,
#  'exceed': 819,
#  'dry': 64,
#  'weight': 311,
#  'basis': 1066,
#  'regulate': 338,
#  'processing': 286,
#  'exclusive': 195,
#  'criminal': 2053,
#  'civil': 1499,
#  'administrative': 650,
#  'proceeding': 402,
#  'limit': 2145,
#  'election': 1711,
#  'prohibit': 6158,
#  'administration': 2848,
#  'official': 1023,
#  'actively': 71,
#  'participate': 1065,
#  'integrity': 347,
#  'unlawful': 327,
#  'chief': 498,
#  'management': 3159,
#  'ensure': 3057,
#  'loan': 3472,
#  'deliver': 201,
#  'possible': 156,
#  'aid': 520,
#  'reward': 111,
#  'title': 10922,
#  'iv': 650,
#  'carry': 2125,
#  'encourage': 997,
#  'institution': 2182,
#  'ihe': 232,
#  'costeffective': 82,
#  'taxpayer': 1878,
#  'designate': 3089,
#  'forest': 1418,
#  'system': 5507,
#  'land': 5242,
#  'virginia': 294,
#  'wilderness': 882,
#  'study': 2181,
#  'area': 4200,
#  'creek': 198,
#  'potential': 568,
#  'mountain': 274,
#  'bear': 379,
#  'scenic': 480,
#  'development': 4512,
#  'trail': 450,
#  'valley': 368,
#  'east': 185,
#  'branch': 438,
#  'hunting': 131,
#  'camp': 135,
#  'lake': 557,
#  'lewis': 61,
#  'addition': 296,
#  'little': 65,
#  'affect': 717,
#  'small': 4035,
#  'business': 5487,
#  'retirement': 1663,
#  'income': 4073,
#  'erisa': 187,
#  'governance': 80,
#  'association': 584,
#  'health': 15658,
#  'group': 1048,
#  'certification': 677,
#  'sponsor': 331,
#  'industry': 542,
#  'professional': 1027,
#  'chamber': 70,
#  'commerce': 1250,
#  'similar': 507,
#  'xxi': 220,
#  'approval': 501,
#  'continuation': 123,
#  'section': 1170,
#  'waiver': 529,
#  'coverage': 2416,
#  'adult': 473,
#  'children': 526,
#  'insurance': 4189,
#  'schip': 247,
#  'amends': 1090,
#  'revise': 1920,
#  'prohibition': 861,
#  'human': 3301,
#  'pilot': 1085,
#  'demonstration': 790,
#  'allow': 5479,
#  'fund': 5691,
#  'available': 2097,
#  'food': 2871,
#  'drug': 3735,
#  'cosmetic': 776,
#  'diagnosis': 182,
#  'treatment': 2820,
#  'heart': 131,
#  'disease': 1452,
#  'woman': 957,
#  'analysis': 493,
#  'research': 3956,
#  'sec': 1201,
#  'deny': 632,
#  'application': 1455,
#  'fail': 372,
#  'include': 7529,
#  'information': 4706,
#  'clinical': 511,
#  'automobile': 389,
#  'dealer': 252,
#  'disclose': 460,
#  'consumer': 2696,
#  'presence': 155,
#  'event': 505,
#  'datum': 1072,
#  'black': 245,
#  'box': 84,
#  'consider': 776,
#  'property': 3631,
#  'vehicle': 2040,
#  'owner': 596,
#  'consent': 404,
#  'court': 1317,
#  'technician': 78,
#  'identity': 420,
#  'register': 539,
#  'driver': 245,
#  'omnibus': 408,
#  'park': 1598,
#  'lands': 237,
#  'interior': 2492,
#  'enter': 1314,
#  'cooperative': 515,
#  'partner': 313,
#  'harbor': 215,
#  'islands': 428,
#  'recreation': 393,
#  'permit': 2130,
#  'consult': 89,
#  'concern': 1234,
#  'acquire': 667,
#  'entity': 2534,
#  'good': 987,
#  'construction': 1353,
#  'facility': 4287,
#  'consistent': 289,
#  'xix': 862,
#  'medicaid': 1517,
#  'item': 522,
#  'furnish': 541,
#  'set': 1162,
#  'developmental': 84,
#  'physical': 711,
#  'mental': 1163,
#  'need': 1317,
#  'protect': 2244,
#  'ssa': 507,
#  'reimbursement': 470,
#  'care': 7846,
#  'special': 1296,
#  'transportation': 2849,
#  'cover': 1103,
#  'manage': 472,
#  'organization': 2608,
#  'animal': 546,
#  'agriculture': 1415,
#  'identification': 568,
#  'obtain': 934,
#  'voluntary': 511,
#  'mandate': 381,
#  'participation': 623,
#  'livestock': 242,
#  'building': 1648,
#  'locate': 2103,
#  'avenue': 233,
#  'puerto': 335,
#  'rico': 329,
#  'build': 327,
#  'strengthen': 853,
#  'expand': 3540,
#  'scientific': 286,
#  'capability': 302,
#  'college': 637,
#  'arrangement': 523,
#  'science': 975,
#  'competitiveness': 241,
#  'statewide': 114,
#  'transition': 451,
#  'transfer': 1760,
#  'twoyear': 131,
#  'fouryear': 62,
#  'common': 229,
#  'core': 117,
#  'math': 55,
#  'engineering': 412,
#  'reflect': 135,
#  'workforce': 883,
#  'private': 1571,
#  'urban': 755,
#  'initiative': 792,
#  'department': 6368,
#  'homeland': 1935,
#  'enhancement': 985,
#  'authorization': 1156,
#  'dhs': 366,
#  'purchase': 1464,
#  'equipment': 975,
#  'conduct': 2508,
#  'exercise': 293,
#  'technical': 1049,
#  'expense': 1743,
#  'personnel': 1068,
#  'relevant': 280,
#  'jurisdiction': 833,
#  'dedicate': 72,
#  'exclusively': 79,
#  'counterterrorism': 71,
#  'intelligence': 794,
#  'activity': 3605,
#  'resource': 2180,
#  'suitability': 222,
#  'feasibility': 478,
#  'historic': 532,
#  'massachusetts': 90,
#  'unit': 1259,
#  'occur': 1311,
#  'assault': 345,
#  'weapon': 330,
#  'ban': 243,
#  'reinstate': 132,
#  'large': 257,
#  'capacity': 596,
#  'ammunition': 198,
#  'device': 1052,
#  'imposition': 101,
#  'withhold': 153,
#  'tax': 9849,
#  'increase': 5306,
#  'reconciliation': 428,
#  'governmental': 309,
#  'issuance': 461,
#  'postage': 53,
#  'stamp': 331,
#  'commemorate': 104,
#  'th': 408,
#  'anniversary': 126,
#  'european': 71,
#  'settlement': 586,
#  'continental': 540,
#  'florida': 301,
#  'de': 175,
#  'water': 4054,
#  'supply': 767,
#  'conservation': 2006,
#  'reliability': 122,
#  'storage': 542,
#  'efficiency': 1136,
#  'river': 1466,
#  'county': 1396,
#  'nebraska': 92,
#  'kansas': 92,
#  'facilitate': 742,
#  'sale': 1779,
#  'agricultural': 809,
#  'cuba': 456,
#  'sanction': 412,
#  'export': 763,
#  'facilitation': 82,
#  'treasury': 1607,
#  'license': 789,
#  'transaction': 741,
#  'travel': 842,
#  'connection': 823,
#  'marketing': 317,
#  'sea': 185,
#  'air': 1625,
#  'code': 14711,
#  'spouse': 796,
#  'recipient': 476,
#  'purple': 60,
#  'associate': 715,
#  'america': 1068,
#  'incorporate': 238,
#  'charter': 291,
#  'corporation': 1752,
#  'membership': 176,
#  'create': 1167,
#  'rural': 1516,
#  'policing': 50,
#  'institute': 505,
#  'center': 2325,
#  'administer': 815,
#  'evaluate': 472,
#  'tribal': 719,
#  'develop': 2329,
#  'expert': 86,
#  'combat': 719,
#  'methamphetamine': 117,
#  'addiction': 70,
#  'distribution': 984,
#  'domestic': 1154,
#  'violence': 700,
#  'shooting': 74,
#  'reach': 186,
#  'officer': 1571,
#  'highway': 1009,
#  'traffic': 563,
#  'disclosure': 1156,
#  'fair': 1145,
#  'market': 1240,
#  'damage': 588,
#  'motor': 936,
#  'issue': 2261,
#  'regulation': 1942,
#  'person': 3374,
#  'terminate': 661,
#  'contract': 2164,
#  'flood': 800,
#  'fire': 562,
#  'theft': 318,
#  'circumstance': 270,
#  'adversely': 105,
#  'presumption': 104,
#  'disability': 2019,
#  'cause': 725,
#  'condition': 1547,
#  'result': 1394,
#  'performance': 867,
#  'fairness': 973,
#  'lung': 114,
#  'cancer': 853,
#  'infectious': 81,
#  'shall': 2150,
#  'employment': 2036,
#  'death': 794,
#  'personal': 792,
#  'sustain': 150,
#  'evidence': 367,
#  'screening': 501,
#  'minority': 333,
#  'underserved': 213,
#  'population': 608,
#  'testing': 432,
#  'nonprofit': 785,
#  'operate': 1055,
#  'counsel': 172,
#  'counseling': 359,
#  'preference': 293,
#  'applicant': 403,
#  'significant': 413,
#  'number': 1742,
#  'lowincome': 683,
#  'atrisk': 107,
#  'early': 701,
#  'detection': 210,
#  'comprehensive': 1059,
#  'stage': 61,
#  'type': 298,
#  'referral': 128,
#  'diabetes': 284,
#  'community': 2934,
#  'provider': 1462,
#  'routine': 71,
#  'patient': 1866,
#  'foot': 90,
#  'kidney': 82,
#  'support': 3165,
#  'alzheimer': 100,
#  'caregiver': 240,
#  'railroad': 360,
#  'maintenance': 620,
#  'protective': 168,
#  'structure': 337,
#  'track': 203,
#  'guard': 964,
#  'youth': 767,
#  'challenge': 227,
#  'match': 232,
#  'defense': 2841,
#  'internal': 9526,
#  'revenue': 9942,
#  'credit': 6813,
#  'donate': 110,
#  'organ': 136,
#  'live': 384,
#  'donor': 114,
#  'donation': 232,
#  'qualified': 2346,
#  'define': 1435,
#  'bone': 66,
#  'thereof': 181,
#  'annual': 1554,
#  'lose': 141,
#  'wage': 864,
#  'incur': 533,
#  'transplant': 52,
#  'administrator': 2036,
#  'convey': 591,
#  'parcel': 310,
#  'real': 841,
#  'alaska': 695,
#  'services': 486,
#  'gsa': 90,
#  'right': 2167,
#  'interest': 1803,
#  'fleet': 85,
#  'suitable': 99,
#  'replacement': 211,
#  'consideration': 519,
#  'agree': 230,
#  'proceed': 267,
#  'deposit': 549,
#  'licensing': 232,
#  'comparable': 113,
#  'biological': 315,
#  'access': 3555,
#  'medicine': 300,
#  'process': 1500,
#  'contain': 1096,
#  'ingredient': 93,
#  'previously': 201,
#  'reference': 82,
#  'file': 713,
#  'demonstrate': 313,
#  'recommend': 226,
#  'labeling': 234,
#  'propose': 759,
#  'approve': 965,
#  'route': 307,
#  'form': 789,
#  'strength': 85,
#  'hope': 136,
#  'site': 950,
#  'oklahoma': 150,
#  'race': 188,
#  'assurance': 102,
#  'planning': 734,
#  'contact': 177,
#  'adoption': 483,
#  'centers': 55,
#  'assure': 147,
#  'list': 805,
#  'flat': 52,
#  'alternative': 1172,
#  'current': 1071,
#  'calculate': 186,
#  'taxable': 648,
#  'basic': 468,
#  'standard': 2560,
#  'dependent': 794,
#  'total': 779,
#  'unemployment': 656,
#  'compensation': 2051,
#  'gross': 1269,
#  'employer': 1779,
#  'engage': 887,
#  'estate': 589,
#  'gift': 261,
#  'generationskippe': 53,
#  'taxis': 868,
#  'house': 1734,
#  'representatives': 415,
#  'enhanced': 318,
#  'funding': 1400,
#  'adequate': 277,
#  'level': 916,
#  'veterans': 3710,
#  'seek': 524,
#  'budget': 1784,
#  'fiscal': 2103,
#  'period': 2790,
#  'review': 1542,
#  'board': 1311,
#  'outline': 57,
#  'determination': 710,
#  'promotion': 575,
#  'extension': 915,
#  'bipartisan': 119,
#  'july': 408,
#  'country': 1560,
#  'tariff': 4096,
#  'burden': 163,
#  'restrict': 422,
#  'economy': 482,
#  'fiveyear': 262,
#  'begin': 845,
#  'april': 261,
#  'rehabilitation': 582,
#  'housing': 2805,
#  'restoration': 894,
#  'revitalization': 133,
#  'adjustment': 1161,
#  'rule': 2243,
#  'qualification': 133,
#  'taxexempt': 552,
#  'exempt': 1196,
#  'recapture': 60,
#  'disaster': 1535,
#  'improvement': 2714,
#  'sba': 366,
#  'guarantee': 653,
#  'principal': 670,
#  'lender': 166,
#  'cap': 245,
#  'street': 1102,
#  'iowa': 65,
#  'smith': 76,
#  'xi': 148,
#  'xviii': 2425,
#  'modernize': 233,
#  'quality': 1390,
#  'medicare': 4555,
#  'modernization': 461,
#  'utilization': 167,
#  'offer': 869,
#  'practitioner': 225,
#  'c': 258,
#  'prescription': 966,
#  'd': 636,
#  'soldier': 112,
#  'memorial': 674,
#  'museum': 360,
#  'st': 418,
#  'missouri': 181,
#  'pass': 835,
#  'surplus': 177,
#  'computer': 380,
#  'communitybase': 160,
#  'deploy': 191,
#  'profit': 125,
#  'identify': 1241,
#  'useful': 50,
#  'declare': 786,
#  'directly': 366,
#  'sarbanesoxley': 51,
#  'maintain': 1094,
#  'confidence': 53,
#  'publicly': 299,
#  'hold': 1169,
#  'company': 1191,
#  'excessive': 197,
#  'corporate': 333,
#  'accounting': 188,
#  'oversight': 612,
#  'appoint': 416,
#  'ombudsman': 62,
#  'firm': 123,
#  'issuer': 425,
#  'dispute': 125,
#  'preparation': 206,
#  'audit': 227,
#  'report': 3776,
#  'problem': 177,
#  'regulatory': 1193,
#  'particularly': 137,
#  'assessment': 886,
#  'northern': 398,
#  'heritage': 755,
#  'committee': 1398,
#  'comprise': 166,
#  'eastern': 84,
#  'coastal': 648,
#  'king': 90,
#  'george': 99,
#  'adjacent': 183,
#  'vicinity': 57,
#  'aspect': 66,
#  'job': 1579,
#  'territory': 301,
#  'responsibility': 667,
#  'unable': 107,
#  'work': 2055,
#  'living': 123,
#  'farm': 597,
#  'freedom': 889,
#  'old': 809,
#  'age': 1583,
#  'collective': 150,
#  'bargaining': 140,
#  'working': 55,
#  'environment': 358,
#  'pollution': 766,
#  'wellbeing': 89,
#  'worker': 1099,
#  'world': 558,
#  'voting': 372,
#  'website': 399,
#  'find': 213,
#  'complete': 589,
#  'database': 299,
#  'scholarship': 380,
#  'fellowship': 82,
#  'mathematics': 84,
#  'stem': 478,
#  'postsecondary': 213,
#  'graduate': 308,
#  'mathematic': 178,
#  'option': 579,
#  'actual': 179,
#  'major': 722,
#  'failure': 332,
#  'army': 752,
#  'corps': 551,
#  'engineer': 396,
#  'design': 1007,
#  'legally': 94,
#  'responsible': 599,
#  'accountability': 1435,
#  'bring': 412,
#  'construct': 377,
#  'impact': 975,
#  'establishe': 486,
#  'california': 924,
#  'share': 557,
#  'district': 1790,
#  'columbia': 996,
#  'home': 2023,
#  'eliminate': 1376,
#  'legislative': 377,
#  'emergency': 3008,
#  'strike': 83,
#  'modification': 295,
#  'frequency': 79,
#  'toxic': 177,
#  'environmental': 2042,
#  'epa': 707,
#  'submit': 1372,
#  'chemical': 435,
#  'release': 538,
#  'tuition': 346,
#  'elementary': 1659,
#  'secondary': 2029,
#  'adjust': 615,
#  'inflation': 338,
#  'attendance': 106,
#  'religious': 358,
#  'organize': 139,
#  'contribute': 234,
#  'charitable': 449,
#  'instructional': 75,
#  'material': 989,
#  'cut': 170,
#  'annually': 322,
#  'distribute': 291,
#  'instruction': 158,
#  'plus': 170,
#  'term': 999,
#  'teacher': 751,
#  'fulltime': 328,
#  'tribe': 1166,
#  'inc': 126,
#  'future': 604,
#  'federally': 457,
#  'recognize': 617,
#  'stafford': 325,
#  'prekindergarten': 113,
#  'kindergarten': 103,
#  'grade': 323,
#  'educator': 144,
#  'position': 616,
#  'regular': 285,
#  'western': 242,
#  'hemisphere': 76,
#  'satisfy': 145,
#  'terrorism': 570,
#  'extent': 354,
#  'iraq': 571,
#  'fully': 231,
#  'cooperate': 69,
#  'stability': 270,
#  'effort': 923,
#  'progress': 217,
#  'achieve': 412,
#  'sanctuary': 99,
#  'day': 1760,
#  'equal': 688,
#  'minor': 296,
#  'line': 438,
#  'involvement': 115,
#  'abortion': 481,
#  'decision': 464,
#  'interstate': 734,
#  'notification': 397,
#  'transport': 418,
#  'residence': 780,
#  'parental': 136,
#  'exception': 528,
#  'necessary': 869,
#  'life': 800,
#  'breast': 272,
#  'december': 949,
#  'postal': 1203,
#  'mail': 283,
#  'streamline': 194,
#  'reinsurance': 145,
#  'investment': 2497,
#  'depository': 265,
#  'coordination': 660,
#  'advanced': 455,
#  'council': 619,
#  'collaboration': 134,
#  'academic': 512,
#  'describe': 280,
#  'advice': 156,
#  'computing': 52,
#  'gang': 206,
#  'designation': 491,
#  'marriage': 274,
#  'legal': 694,
#  'consist': 244,
#  'union': 386,
#  'man': 133,
#  'justice': 1177,
#  'resistance': 69,
#  'nonimmigrant': 235,
#  'alien': 1265,
#  'september': 1027,
#  'status': 912,
#  'lawfully': 109,
#  'admit': 137,
#  'permanent': 1611,
#  'humanitarian': 142,
#  'resident': 745,
#  'present': 415,
#  'son': 53,
#  'daughter': 53,
#  'lawful': 234,
#  'die': 265,
#  'beneficiary': 901,
#  'victim': 980,
#  'womens': 308,
#  'coordinate': 676,
#  'function': 480,
#  'hhs': 1125,
#  'chapter': 454,
#  'respectively': 66,
#  'inclusion': 355,
#  'fer': 84,
#  'csr': 63,
#  'convict': 341,
#  'firearm': 1266,
#  'irs': 241,
#  'primarily': 150,
#  'delinquent': 107,
#  'return': 947,
#  'pregnancy': 185,
#  'help': 901,
#  'healthy': 427,
#  'teen': 61,
#  'infrastructure': 1123,
#  'bond': 889,
#  'bank': 829,
#  'financing': 526,
#  'samoa': 166,
#  'guam': 171,
#  'virgin': 266,
#  'mariana': 215,
#  'island': 483,
#  'refinance': 161,
#  ...}

# %% [markdown]
# **Putting it back together**

# %%
df_document_topic.reset_index(drop=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
test = pd.concat([df_document_topic, df], axis=1)

# %%
test.head()

# %%
#Looking at dominant topic contribution by proportion
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# %matplotlib inline

# plt.figure(figsize=(20,5))

# x1, y1, hue = "top_word", "proportion", "Cong"
# hue_order = ["1", "0"]
# data=test

# (test[x1]
#  .groupby(test[hue])
#  .value_counts(normalize=True)
#  .rename(y1)
#  .reset_index()
#  .pipe((sns.barplot, "data"), x=x1, y=y1, hue=hue).set_title('Bill Topic Percentage Proposals by Congress'))

# %%
#Dataframe of lemmas
lemma_df = pd.DataFrame.from_dict(more_words, orient='index', columns=['count'])
lemma_df = lemma_df.reset_index()
lemma_df.head()

# %%
#review of the top words
for word in sorted(more_words, key=more_words.get, reverse=True):
    print(word, more_words[word])

# %% [markdown]
# **t-SNE**

# %% [markdown]
# # Adding Words to MySQL:
#
# Create a separate table for topics and link with BillID Primary Key

# %% [markdown]
# https://stackoverflow.com/questions/53518217/adding-topic-distribution-outcome-of-topic-model-to-pandas-dataframe

# %%
#make sure it is the right shape first!
test.shape

# %%
test.head()

# %%
test2 = test.drop(columns=['IntrDate', 'PLawNum', 'PLawDate'])

# %%
test2.head()

# %%
final_topics = test2.to_dict(orient = 'records')
final_topics[0]

# %%
# from schema import DbSchema

# bills_db = DbSchema(config_final)

# %%
# query = db.insert(bills_db.topics_table)
# bills_db.connection.execute(query, final_topics)
